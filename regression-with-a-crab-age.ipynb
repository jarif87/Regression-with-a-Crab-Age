# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import early_stopping
import lightgbm as lgb
# %matplotlib inline

# %%
df_train=pd.read_csv("/kaggle/input/playground-series-s3e16/train.csv")
df_test=pd.read_csv("/kaggle/input/playground-series-s3e16/test.csv")

# %%
df_train.head()
# Out:
#    id Sex  Length  Diameter  Height     Weight  Shucked Weight  \
# 0   0   I  1.5250    1.1750  0.3750  28.973189       12.728926
# 1   1   I  1.1000    0.8250  0.2750  10.418441        4.521745
# 2   2   M  1.3875    1.1125  0.3750  24.777463       11.339800
# 3   3   F  1.7000    1.4125  0.5000  50.660556       20.354941
# 4   4   I  1.2500    1.0125  0.3375  23.289114       11.977664
#
#    Viscera Weight  Shell Weight  Age
# 0        6.647958      8.348928    9
# 1        2.324659      3.401940    8
# 2        5.556502      6.662133    9
# 3       10.991839     14.996885   11
# 4        4.507570      5.953395    8

# %%
df_test.head()
# Out:
#       id Sex  Length  Diameter  Height     Weight  Shucked Weight  \
# 0  74051   I  1.0500    0.7625  0.2750   8.618248        3.657085
# 1  74052   I  1.1625    0.8875  0.2750  15.507176        7.030676
# 2  74053   F  1.2875    0.9875  0.3250  14.571643        5.556502
# 3  74054   F  1.5500    0.9875  0.3875  28.377849       13.380964
# 4  74055   I  1.1125    0.8500  0.2625  11.765042        5.528153
#
#    Viscera Weight  Shell Weight
# 0        1.729319      2.721552
# 1        3.246018      3.968930
# 2        3.883882      4.819415
# 3        6.548735      7.030676
# 4        2.466407      3.331066

# %% [markdown]
# # Data Analysis

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74051 entries, 0 to 74050
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              74051 non-null  int64
#  1   Sex             74051 non-null  object
#  2   Length          74051 non-null  float64
#  3   Diameter        74051 non-null  float64
#  4   Height          74051 non-null  float64
#  5   Weight          74051 non-null  float64
#  6   Shucked Weight  74051 non-null  float64
#  7   Viscera Weight  74051 non-null  float64
#  8   Shell Weight    74051 non-null  float64
#  9   Age             74051 non-null  int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 5.6+ MB

# %%
df_train.describe()
# Out:
#                  id        Length      Diameter        Height        Weight  \
# count  74051.000000  74051.000000  74051.000000  74051.000000  74051.000000
# mean   37025.000000      1.317460      1.024496      0.348089     23.385217
# std    21376.826729      0.287757      0.237396      0.092034     12.648153
# min        0.000000      0.187500      0.137500      0.000000      0.056699
# 25%    18512.500000      1.150000      0.887500      0.300000     13.437663
# 50%    37025.000000      1.375000      1.075000      0.362500     23.799405
# 75%    55537.500000      1.537500      1.200000      0.412500     32.162508
# max    74050.000000      2.012815      1.612500      2.825000     80.101512
#
#        Shucked Weight  Viscera Weight  Shell Weight           Age
# count    74051.000000    74051.000000  74051.000000  74051.000000
# mean        10.104270        5.058386      6.723870      9.967806
# std          5.618025        2.792729      3.584372      3.175189
# min          0.028349        0.042524      0.042524      1.000000
# 25%          5.712424        2.863300      3.968930      8.000000
# 50%          9.908150        4.989512      6.931453     10.000000
# 75%         14.033003        6.988152      9.071840     11.000000
# max         42.184056       21.545620     28.491248     29.000000

# %%
df_train.isnull().sum()
# Out:
# id                0
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Weight            0
# Shucked Weight    0
# Viscera Weight    0
# Shell Weight      0
# Age               0
# dtype: int64

# %%
df_train["Sex"].value_counts()
# Out:
# M    27084
# I    23957
# F    23010
# Name: Sex, dtype: int64

# %%
df_test.describe()
# Out:
#                   id        Length      Diameter        Height        Weight  \
# count   49368.000000  49368.000000  49368.000000  49368.000000  49368.000000
# mean    98734.500000      1.319795      1.026357      0.348693     23.464627
# std     14251.458382      0.286950      0.236593      0.092259     12.641703
# min     74051.000000      0.187500      0.137500      0.000000      0.056699
# 25%     86392.750000      1.162500      0.887500      0.300000     13.536886
# 50%     98734.500000      1.387500      1.075000      0.362500     23.813580
# 75%    111076.250000      1.537500      1.200000      0.412500     32.290081
# max    123418.000000      2.037500      1.625000      2.825000     80.101512
#
#        Shucked Weight  Viscera Weight  Shell Weight
# count    49368.000000    49368.000000  49368.000000
# mean        10.130220        5.072615      6.745876
# std          5.611779        2.791563      3.575650
# min          0.028349        0.014175      0.042524
# 25%          5.740774        2.877474      3.968930
# 50%          9.979024        4.989512      6.945627
# 75%         14.047177        7.016501      9.171063
# max         42.184056       21.545620     28.491248

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49368 entries, 0 to 49367
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              49368 non-null  int64
#  1   Sex             49368 non-null  object
#  2   Length          49368 non-null  float64
#  3   Diameter        49368 non-null  float64
#  4   Height          49368 non-null  float64
#  5   Weight          49368 non-null  float64
#  6   Shucked Weight  49368 non-null  float64
#  7   Viscera Weight  49368 non-null  float64
#  8   Shell Weight    49368 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 3.4+ MB

# %%
df_test.isnull().sum()
# Out:
# id                0
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Weight            0
# Shucked Weight    0
# Viscera Weight    0
# Shell Weight      0
# dtype: int64

# %% [markdown]
# # Data Correlation Heatmap

# %%
plt.figure(figsize=(10,10))
my_corr=df_train.corr()
sns.heatmap(my_corr,vmin=-1,vmax=1,annot=True,cmap="coolwarm")
plt.show()
# Out:
# /tmp/ipykernel_155/1048663316.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   my_corr=df_train.corr()

# %%
plt.figure(figsize=(7,5))
sns.countplot(data=df_train,x="Sex")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df_train, x="Shucked Weight",hue="Sex",kde=True)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df_train, x="Shell Weight",hue="Sex",kde=True)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.histplot(data=df_train, x="Viscera Weight",hue="Sex",kde=True)
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(data=df_train, x="Height", y="Weight", hue="Sex", style="Sex")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(data=df_train, x="Shucked Weight", y="Viscera Weight", hue="Sex", style="Sex")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(data=df_train, x="Length", y="Diameter", hue="Sex", style="Sex")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.lineplot(data=df_train, x="Age", y="Diameter",hue="Sex",style="Sex")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.lineplot(data=df_train, x="Age", y="Viscera Weight",hue="Sex",style="Sex")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.lineplot(data=df_train, x="Age", y="Shucked Weight",hue="Sex",style="Sex")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=df_train[["Shucked Weight", "Weight","Viscera Weight"]], orient="h")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=df_train, y="Age", x="Sex", hue="Sex")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=df_train, y="Shell Weight", x="Sex", hue="Sex")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=df_train, y="Shucked Weight", x="Sex", hue="Sex")
plt.show()

# %%
label_encoder = LabelEncoder()
df_train["Sex"]=label_encoder.fit_transform(df_train["Sex"])
df_train.drop("id",axis=1,inplace=True)
df_train.head()
# Out:
#    Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0    1  1.5250    1.1750  0.3750  28.973189       12.728926        6.647958
# 1    1  1.1000    0.8250  0.2750  10.418441        4.521745        2.324659
# 2    2  1.3875    1.1125  0.3750  24.777463       11.339800        5.556502
# 3    0  1.7000    1.4125  0.5000  50.660556       20.354941       10.991839
# 4    1  1.2500    1.0125  0.3375  23.289114       11.977664        4.507570
#
#    Shell Weight  Age
# 0      8.348928    9
# 1      3.401940    8
# 2      6.662133    9
# 3     14.996885   11
# 4      5.953395    8

# %%
scaler = StandardScaler()
col_scale = ["Sex",'Length', 'Diameter', 'Height', 'Weight', 'Shucked Weight', 'Viscera Weight', 'Shell Weight']
df_train[col_scale] = scaler.fit_transform(df_train[col_scale])

# %%
df_train.head()
# Out:
#         Sex    Length  Diameter    Height    Weight  Shucked Weight  \
# 0 -0.067040  0.721238  0.633982  0.292400  0.441804        0.467188
# 1 -0.067040 -0.755712 -0.840356 -0.794163 -1.025198       -0.993688
# 2  1.151518  0.243401  0.370707  0.292400  0.110076        0.219924
# 3 -1.285599  1.329394  1.634426  1.650603  2.156483        1.824616
# 4 -0.067040 -0.234435 -0.050532 -0.115061 -0.007598        0.333464
#
#    Viscera Weight  Shell Weight  Age
# 0        0.569186      0.453376    9
# 1       -0.978880     -0.926788    8
# 2        0.178363     -0.017224    9
# 3        2.124622      2.308095   11
# 4       -0.197233     -0.214955    8

# %% [markdown]
# # Train aNd Label Data

# %%
col_scale = ["Sex",'Length', 'Diameter', 'Height', 'Weight', 'Shucked Weight', 'Viscera Weight', 'Shell Weight']
train_data=df_train[col_scale]

# %%
label_data=df_train["Age"]

# %% [markdown]
# # Split Data

# %%
X_train,X_test,Y_train,Y_test=train_test_split(train_data,label_data,test_size=0.2,random_state=42)

# %% [markdown]
# # LinearRegression Model

# %%
ln_model=LinearRegression()
ln_model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # MSE,MAE,R2_SCORE_LinearRegressionModel

# %%
ln_pred=ln_model.predict(X_test)
mse = mean_squared_error(Y_test,ln_pred)
print("Mean Squared Error:", mse)
mae = mean_absolute_error(Y_test,ln_pred)
print("Mean Absolute Error:", mae)
r2 = r2_score(Y_test,ln_pred)
print("R2 Score:", r2)
# Out:
# Mean Squared Error: 4.643868776399207
# Mean Absolute Error: 1.5115362205225142
# R2 Score: 0.5443420195547682

# %%
plt.figure(figsize=(7,5))
sns.regplot(x=Y_test,y=ln_pred,color="navy",line_kws={'linewidth': 3},scatter=False)
sns.scatterplot(x=Y_test, y=ln_pred,color="darkgreen",marker="H",s=100)

plt.show()

# %% [markdown]
# # RandomForestRegressor Model

# %%
random_regr= RandomForestRegressor(random_state=0)
random_regr.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %% [markdown]
# # MSE,MAE,R2 Score_RandomForestRegressor

# %%
rfr_pred=random_regr.predict(X_test)
mse1 = mean_squared_error(Y_test,rfr_pred)
print("Mean Squared Error:", mse1)
mae1= mean_absolute_error(Y_test,rfr_pred)
print("Mean Absolute Error:", mae1)
r21 = r2_score(Y_test,rfr_pred)
print("R2 Score:", r21)
# Out:
# Mean Squared Error: 4.380638390385524
# Mean Absolute Error: 1.463027479575991
# R2 Score: 0.5701702743694564

# %%
plt.figure(figsize=(7,5))
sns.regplot(x=Y_test,y=rfr_pred,color="navy",line_kws={'linewidth': 3},scatter=False)
sns.scatterplot(x=Y_test, y=rfr_pred,color="crimson",marker="*",s=100)

plt.show()

# %% [markdown]
# # GradientBoostingRegressor Model

# %%
gb= GradientBoostingRegressor(random_state=0)
gb.fit(X_train,Y_train)
# Out:
# GradientBoostingRegressor(random_state=0)

# %% [markdown]
# # MSE,MAE,R2 SCORE_GradientBoostingRegressor

# %%
gb_pred=gb.predict(X_test)
mse2 = mean_squared_error(Y_test,gb_pred)
print("Mean Squared Error:", mse2)
mae2= mean_absolute_error(Y_test,gb_pred)
print("Mean Absolute Error:", mae2)
r22 = r2_score(Y_test,gb_pred)
print("R2 Score:", r22)
# Out:
# Mean Squared Error: 4.236092700395076
# Mean Absolute Error: 1.424291701330586
# R2 Score: 0.5843531465293756

# %%
plt.figure(figsize=(7,5))
sns.regplot(x=Y_test,y=gb_pred,color="black",line_kws={'linewidth': 3},scatter=False)
sns.scatterplot(x=Y_test, y=gb_pred,color="red",marker="D",s=80)

plt.show()

# %% [markdown]
# # XGBRegressor Model

# %%
xgb = XGBRegressor()
xgb.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %% [markdown]
# # MSE,MAE,R2_XGBRegressor Model

# %%
xgb_pred=xgb.predict(X_test)
mse3 = mean_squared_error(Y_test,xgb_pred)
print("Mean Squared Error:", mse3)
mae3= mean_absolute_error(Y_test,xgb_pred)
print("Mean Absolute Error:", mae3)
r23 = r2_score(Y_test,xgb_pred)
print("R2 Score:", r23)
# Out:
# Mean Squared Error: 4.252950343517826
# Mean Absolute Error: 1.419246059387719
# R2 Score: 0.5826990688647748

# %%
plt.figure(figsize=(7,5))
sns.regplot(x=Y_test,y=xgb_pred,color="green",line_kws={'linewidth': 3},scatter=False)
sns.scatterplot(x=Y_test, y=xgb_pred,color="darkblue",marker="o",s=80)

plt.show()

# %% [markdown]
# # Ridge Model

# %%
rd=Ridge(alpha=1.0)
rd.fit(X_train,Y_train)
# Out:
# Ridge()

# %%
rd_pred=rd.predict(X_test)
mse4 = mean_squared_error(Y_test,rd_pred)
print("Mean Squared Error:", mse4)
mae4= mean_absolute_error(Y_test,rd_pred)
print("Mean Absolute Error:", mae4)
r24 = r2_score(Y_test,rd_pred)
print("R2 Score:", r24)
# Out:
# Mean Squared Error: 4.643827674164782
# Mean Absolute Error: 1.51152366542958
# R2 Score: 0.5443460525199599

# %%
plt.figure(figsize=(7,5))
sns.regplot(x=Y_test,y=rd_pred,color="brown",line_kws={'linewidth': 3},scatter=False)
sns.scatterplot(x=Y_test, y=rd_pred,color="purple",marker="v",s=80)

plt.show()

# %% [markdown]
# # Create LGB Model

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': ['rmse','mae'],
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

# %%
lgb_train = lgb.Dataset(X_train, Y_train)
lgb_eval = lgb.Dataset(X_test, Y_test, reference=lgb_train)
callbacks = [lgb.early_stopping(40),lgb.log_evaluation()]
lgb_model = lgb.train(params,train_set=lgb_train,valid_sets=[lgb_train, lgb_eval],callbacks=callbacks)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004464 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [1]	training's rmse: 3.08605	training's l1: 2.25538	valid_1's rmse: 3.10647	valid_1's l1: 2.27756
# Training until validation scores don't improve for 40 rounds
# [2]	training's rmse: 3.0077	training's l1: 2.19967	valid_1's rmse: 3.02674	valid_1's l1: 2.21989
# [3]	training's rmse: 2.93436	training's l1: 2.14593	valid_1's rmse: 2.9522	valid_1's l1: 2.16449
# [4]	training's rmse: 2.86719	training's l1: 2.09628	valid_1's rmse: 2.88382	valid_1's l1: 2.11332
# [5]	training's rmse: 2.80392	training's l1: 2.04779	valid_1's rmse: 2.81971	valid_1's l1: 2.06371
# [6]	training's rmse: 2.74501	training's l1: 2.00241	valid_1's rmse: 2.75997	valid_1's l1: 2.01726
# [7]	training's rmse: 2.69478	training's l1: 1.96231	valid_1's rmse: 2.70955	valid_1's l1: 1.97687
# [8]	training's rmse: 2.64708	training's l1: 1.92374	valid_1's rmse: 2.66116	valid_1's l1: 1.93754
# [9]	training's rmse: 2.59981	training's l1: 1.88595	valid_1's rmse: 2.6138	valid_1's l1: 1.89946
# [10]	training's rmse: 2.5591	training's l1: 1.85281	valid_1's rmse: 2.57265	valid_1's l1: 1.866
# [11]	training's rmse: 2.5181	training's l1: 1.82015	valid_1's rmse: 2.53111	valid_1's l1: 1.83273
# [12]	training's rmse: 2.48073	training's l1: 1.79052	valid_1's rmse: 2.49336	valid_1's l1: 1.8026
# [13]	training's rmse: 2.44593	training's l1: 1.76281	valid_1's rmse: 2.45852	valid_1's l1: 1.77478
# [14]	training's rmse: 2.4139	training's l1: 1.73653	valid_1's rmse: 2.42616	valid_1's l1: 1.74811
# [15]	training's rmse: 2.38462	training's l1: 1.71287	valid_1's rmse: 2.39652	valid_1's l1: 1.72418
# [16]	training's rmse: 2.35719	training's l1: 1.68966	valid_1's rmse: 2.36899	valid_1's l1: 1.70109
# [17]	training's rmse: 2.33209	training's l1: 1.66814	valid_1's rmse: 2.34374	valid_1's l1: 1.67973
# [18]	training's rmse: 2.31097	training's l1: 1.64976	valid_1's rmse: 2.32259	valid_1's l1: 1.66144
# [19]	training's rmse: 2.28957	training's l1: 1.63154	valid_1's rmse: 2.3015	valid_1's l1: 1.64365
# [20]	training's rmse: 2.27065	training's l1: 1.61518	valid_1's rmse: 2.28259	valid_1's l1: 1.62765
# [21]	training's rmse: 2.25203	training's l1: 1.59947	valid_1's rmse: 2.26386	valid_1's l1: 1.6117
# [22]	training's rmse: 2.23485	training's l1: 1.58487	valid_1's rmse: 2.24635	valid_1's l1: 1.59689
# [23]	training's rmse: 2.22106	training's l1: 1.5727	valid_1's rmse: 2.23272	valid_1's l1: 1.58472
# [24]	training's rmse: 2.20637	training's l1: 1.55995	valid_1's rmse: 2.21813	valid_1's l1: 1.57222
# [25]	training's rmse: 2.19342	training's l1: 1.54851	valid_1's rmse: 2.20558	valid_1's l1: 1.56119
# [26]	training's rmse: 2.18086	training's l1: 1.53718	valid_1's rmse: 2.19296	valid_1's l1: 1.54991
# [27]	training's rmse: 2.1695	training's l1: 1.52703	valid_1's rmse: 2.18154	valid_1's l1: 1.53959
# [28]	training's rmse: 2.15942	training's l1: 1.51776	valid_1's rmse: 2.17156	valid_1's l1: 1.53036
# [29]	training's rmse: 2.14991	training's l1: 1.50891	valid_1's rmse: 2.16238	valid_1's l1: 1.52182
# [30]	training's rmse: 2.141	training's l1: 1.50057	valid_1's rmse: 2.1537	valid_1's l1: 1.51384
# [31]	training's rmse: 2.13259	training's l1: 1.49289	valid_1's rmse: 2.14551	valid_1's l1: 1.50633
# [32]	training's rmse: 2.1256	training's l1: 1.48639	valid_1's rmse: 2.13872	valid_1's l1: 1.50013
# [33]	training's rmse: 2.1184	training's l1: 1.47979	valid_1's rmse: 2.13177	valid_1's l1: 1.49367
# [34]	training's rmse: 2.11182	training's l1: 1.47358	valid_1's rmse: 2.12522	valid_1's l1: 1.48748
# [35]	training's rmse: 2.1057	training's l1: 1.46793	valid_1's rmse: 2.11942	valid_1's l1: 1.48207
# [36]	training's rmse: 2.09984	training's l1: 1.46241	valid_1's rmse: 2.11364	valid_1's l1: 1.4766
# [37]	training's rmse: 2.09448	training's l1: 1.45753	valid_1's rmse: 2.10849	valid_1's l1: 1.47182
# [38]	training's rmse: 2.08952	training's l1: 1.45283	valid_1's rmse: 2.10381	valid_1's l1: 1.46742
# [39]	training's rmse: 2.08481	training's l1: 1.44836	valid_1's rmse: 2.09941	valid_1's l1: 1.46319
# [40]	training's rmse: 2.08053	training's l1: 1.4443	valid_1's rmse: 2.09512	valid_1's l1: 1.45912
# [41]	training's rmse: 2.07665	training's l1: 1.44076	valid_1's rmse: 2.09169	valid_1's l1: 1.45586
# [42]	training's rmse: 2.07314	training's l1: 1.4374	valid_1's rmse: 2.08841	valid_1's l1: 1.45276
# [43]	training's rmse: 2.06971	training's l1: 1.43418	valid_1's rmse: 2.08539	valid_1's l1: 1.44977
# [44]	training's rmse: 2.0665	training's l1: 1.43118	valid_1's rmse: 2.08246	valid_1's l1: 1.44706
# [45]	training's rmse: 2.06344	training's l1: 1.4282	valid_1's rmse: 2.07974	valid_1's l1: 1.44436
# [46]	training's rmse: 2.06077	training's l1: 1.42568	valid_1's rmse: 2.0777	valid_1's l1: 1.44226
# [47]	training's rmse: 2.05796	training's l1: 1.42304	valid_1's rmse: 2.07512	valid_1's l1: 1.43987
# [48]	training's rmse: 2.05556	training's l1: 1.42096	valid_1's rmse: 2.07332	valid_1's l1: 1.43819
# [49]	training's rmse: 2.05329	training's l1: 1.41904	valid_1's rmse: 2.07154	valid_1's l1: 1.43654
# [50]	training's rmse: 2.05143	training's l1: 1.41742	valid_1's rmse: 2.07013	valid_1's l1: 1.43515
# [51]	training's rmse: 2.04926	training's l1: 1.41554	valid_1's rmse: 2.06826	valid_1's l1: 1.43336
# [52]	training's rmse: 2.04728	training's l1: 1.4138	valid_1's rmse: 2.06654	valid_1's l1: 1.4318
# [53]	training's rmse: 2.04564	training's l1: 1.41243	valid_1's rmse: 2.06564	valid_1's l1: 1.43083
# [54]	training's rmse: 2.04395	training's l1: 1.41083	valid_1's rmse: 2.06433	valid_1's l1: 1.42955
# [55]	training's rmse: 2.04232	training's l1: 1.40943	valid_1's rmse: 2.06336	valid_1's l1: 1.4286
# [56]	training's rmse: 2.0406	training's l1: 1.40791	valid_1's rmse: 2.0621	valid_1's l1: 1.42741
# [57]	training's rmse: 2.03877	training's l1: 1.40636	valid_1's rmse: 2.06064	valid_1's l1: 1.42619
# [58]	training's rmse: 2.03712	training's l1: 1.40502	valid_1's rmse: 2.05938	valid_1's l1: 1.42506
# [59]	training's rmse: 2.03547	training's l1: 1.40365	valid_1's rmse: 2.05807	valid_1's l1: 1.42402
# [60]	training's rmse: 2.03401	training's l1: 1.4024	valid_1's rmse: 2.0569	valid_1's l1: 1.42304
# [61]	training's rmse: 2.03258	training's l1: 1.40124	valid_1's rmse: 2.05596	valid_1's l1: 1.42224
# [62]	training's rmse: 2.03149	training's l1: 1.40039	valid_1's rmse: 2.05533	valid_1's l1: 1.4216
# [63]	training's rmse: 2.03013	training's l1: 1.39923	valid_1's rmse: 2.05427	valid_1's l1: 1.42064
# [64]	training's rmse: 2.02881	training's l1: 1.39819	valid_1's rmse: 2.05332	valid_1's l1: 1.4198
# [65]	training's rmse: 2.02771	training's l1: 1.39732	valid_1's rmse: 2.05279	valid_1's l1: 1.41925
# [66]	training's rmse: 2.02663	training's l1: 1.39637	valid_1's rmse: 2.05206	valid_1's l1: 1.4185
# [67]	training's rmse: 2.02553	training's l1: 1.39546	valid_1's rmse: 2.05142	valid_1's l1: 1.41788
# [68]	training's rmse: 2.02477	training's l1: 1.39477	valid_1's rmse: 2.05113	valid_1's l1: 1.41746
# [69]	training's rmse: 2.02362	training's l1: 1.39378	valid_1's rmse: 2.05017	valid_1's l1: 1.41657
# [70]	training's rmse: 2.02269	training's l1: 1.393	valid_1's rmse: 2.04966	valid_1's l1: 1.41601
# [71]	training's rmse: 2.02169	training's l1: 1.39212	valid_1's rmse: 2.04913	valid_1's l1: 1.41549
# [72]	training's rmse: 2.02067	training's l1: 1.39125	valid_1's rmse: 2.04831	valid_1's l1: 1.41481
# [73]	training's rmse: 2.01973	training's l1: 1.39057	valid_1's rmse: 2.0477	valid_1's l1: 1.41438
# [74]	training's rmse: 2.01884	training's l1: 1.38993	valid_1's rmse: 2.04736	valid_1's l1: 1.41407
# [75]	training's rmse: 2.01798	training's l1: 1.38928	valid_1's rmse: 2.0469	valid_1's l1: 1.41365
# [76]	training's rmse: 2.01719	training's l1: 1.38885	valid_1's rmse: 2.04653	valid_1's l1: 1.41353
# [77]	training's rmse: 2.01632	training's l1: 1.38836	valid_1's rmse: 2.04622	valid_1's l1: 1.41336
# [78]	training's rmse: 2.01566	training's l1: 1.38807	valid_1's rmse: 2.04607	valid_1's l1: 1.41328
# [79]	training's rmse: 2.01485	training's l1: 1.38755	valid_1's rmse: 2.04574	valid_1's l1: 1.41307
# [80]	training's rmse: 2.01427	training's l1: 1.38727	valid_1's rmse: 2.04565	valid_1's l1: 1.41304
# [81]	training's rmse: 2.01333	training's l1: 1.38662	valid_1's rmse: 2.04523	valid_1's l1: 1.41261
# [82]	training's rmse: 2.01264	training's l1: 1.38607	valid_1's rmse: 2.04502	valid_1's l1: 1.41236
# [83]	training's rmse: 2.01196	training's l1: 1.38567	valid_1's rmse: 2.04493	valid_1's l1: 1.41226
# [84]	training's rmse: 2.01145	training's l1: 1.38536	valid_1's rmse: 2.04456	valid_1's l1: 1.41208
# [85]	training's rmse: 2.01084	training's l1: 1.3849	valid_1's rmse: 2.0446	valid_1's l1: 1.41193
# [86]	training's rmse: 2.01002	training's l1: 1.38431	valid_1's rmse: 2.04389	valid_1's l1: 1.41152
# [87]	training's rmse: 2.0093	training's l1: 1.38387	valid_1's rmse: 2.04367	valid_1's l1: 1.41142
# [88]	training's rmse: 2.00871	training's l1: 1.38353	valid_1's rmse: 2.04347	valid_1's l1: 1.41133
# [89]	training's rmse: 2.008	training's l1: 1.38311	valid_1's rmse: 2.0432	valid_1's l1: 1.41114
# [90]	training's rmse: 2.00707	training's l1: 1.3825	valid_1's rmse: 2.0429	valid_1's l1: 1.41085
# [91]	training's rmse: 2.00649	training's l1: 1.38218	valid_1's rmse: 2.04269	valid_1's l1: 1.41069
# [92]	training's rmse: 2.00565	training's l1: 1.38167	valid_1's rmse: 2.04218	valid_1's l1: 1.41036
# [93]	training's rmse: 2.00507	training's l1: 1.38134	valid_1's rmse: 2.04201	valid_1's l1: 1.41031
# [94]	training's rmse: 2.00436	training's l1: 1.38092	valid_1's rmse: 2.04167	valid_1's l1: 1.4101
# [95]	training's rmse: 2.00381	training's l1: 1.38066	valid_1's rmse: 2.04139	valid_1's l1: 1.41004
# [96]	training's rmse: 2.00317	training's l1: 1.38023	valid_1's rmse: 2.04131	valid_1's l1: 1.4099
# [97]	training's rmse: 2.00262	training's l1: 1.37986	valid_1's rmse: 2.04126	valid_1's l1: 1.40981
# [98]	training's rmse: 2.00215	training's l1: 1.37955	valid_1's rmse: 2.04131	valid_1's l1: 1.40983
# [99]	training's rmse: 2.00152	training's l1: 1.37909	valid_1's rmse: 2.04128	valid_1's l1: 1.40965
# [100]	training's rmse: 2.00102	training's l1: 1.37875	valid_1's rmse: 2.04129	valid_1's l1: 1.40956
# Did not meet early stopping. Best iteration is:
# [100]	training's rmse: 2.00102	training's l1: 1.37875	valid_1's rmse: 2.04129	valid_1's l1: 1.40956

# %%
lgb_pred=lgb_model.predict(X_test)
mse5 = mean_squared_error(Y_test,lgb_pred)
print("Mean Squared Error:", mse5)
mae5= mean_absolute_error(Y_test,lgb_pred)
print("Mean Absolute Error:", mae5)
r25 = r2_score(Y_test,lgb_pred)
print("R2 Score:", r25)
# Out:
# Mean Squared Error: 4.166874663977604
# Mean Absolute Error: 1.4095643296088487
# R2 Score: 0.5911448437549001

# %%
plt.figure(figsize=(7,5))
sns.regplot(x=Y_test,y=lgb_pred,color="red",line_kws={'linewidth': 3},scatter=False)
sns.scatterplot(x=Y_test, y=lgb_pred,color="olive",marker="v",s=80)

plt.show()

# %% [markdown]
# # Create CatBoost Model

# %%
cat_model = CatBoostRegressor(iterations=1000,loss_function='RMSE',learning_rate=0.1,depth=6,
                              random_seed=42,l2_leaf_reg=3)

cat_model.fit( X_train, Y_train,eval_set=(X_test, Y_test), early_stopping_rounds=100,verbose=100)
# Out:
# 0:	learn: 3.0283643	test: 3.0480198	best: 3.0480198 (0)	total: 57.1ms	remaining: 57s
# 100:	learn: 2.0443769	test: 2.0602499	best: 2.0600232 (99)	total: 717ms	remaining: 6.38s
# 200:	learn: 2.0044021	test: 2.0420948	best: 2.0420765 (199)	total: 1.33s	remaining: 5.3s
# 300:	learn: 1.9764843	test: 2.0369101	best: 2.0365439 (276)	total: 1.95s	remaining: 4.53s
# 400:	learn: 1.9505807	test: 2.0345964	best: 2.0345964 (400)	total: 2.59s	remaining: 3.87s
# 500:	learn: 1.9303408	test: 2.0334616	best: 2.0332437 (486)	total: 3.21s	remaining: 3.2s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 2.033243714
# bestIteration = 486
#
# Shrink model to first 487 iterations.

# %%
cat_pred=cat_model.predict(X_test)
mse6 = mean_squared_error(Y_test,cat_pred)
print("Mean Squared Error:", mse6)
mae6= mean_absolute_error(Y_test,cat_pred)
print("Mean Absolute Error:", mae6)
r26 = r2_score(Y_test,cat_pred)
print("R2 Score:", r26)
# Out:
# Mean Squared Error: 4.134080001316325
# Mean Absolute Error: 1.4056714490703317
# R2 Score: 0.5943626671855629

# %%
plt.figure(figsize=(7,5))
sns.regplot(x=Y_test,y=cat_pred,color="indigo",line_kws={'linewidth': 3},scatter=False)
sns.scatterplot(x=Y_test, y=cat_pred,color="orangered",marker="p",s=80)

plt.show()

# %% [markdown]
# # All Model Result Comparison

# %%
all_mse_score = [mse, mse1, mse2, mse3, mse4, mse5, mse6]
all_mae_score = [mae, mae1, mae2, mae4, mae4, mae5, mae6]
all_r2_score = [r2, r21, r22, r23, r24, r25, r26]
all_model = ['ln_model', 'random_regr', 'gb', 'xgb', 'rd', 'lgb_model', 'cat_model']

data = {'Model': all_model,'MSE': all_mse_score,'MAE': all_mae_score,'R2_Score': all_r2_score}
df = pd.DataFrame(data)

df
# Out:
#          Model       MSE       MAE  R2_Score
# 0     ln_model  4.643869  1.511536  0.544342
# 1  random_regr  4.380638  1.463027  0.570170
# 2           gb  4.236093  1.424292  0.584353
# 3          xgb  4.252950  1.511524  0.582699
# 4           rd  4.643828  1.511524  0.544346
# 5    lgb_model  4.166875  1.409564  0.591145
# 6    cat_model  4.134080  1.405671  0.594363

# %%
plt.figure(figsize=(7, 5))
sns.barplot(y="Model", x="R2_Score", data=df, palette="Dark2")
plt.title('R2 Score Comparison')
plt.xlabel('R2 Score')
plt.ylabel('Model')
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.barplot(y="Model", x="MSE", data=df, palette="Set1")
plt.title('MSE Score Comparison')
plt.xlabel('MSE Score')
plt.ylabel('Model')
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.barplot(y="Model", x="MAE", data=df, palette="tab10")
plt.title('MAE Score Comparison')
plt.xlabel('MAE Score')
plt.ylabel('Model')
plt.show()

# %% [markdown]
# # Test Data Analysis

# %%
df_test.head()
# Out:
#       id Sex  Length  Diameter  Height     Weight  Shucked Weight  \
# 0  74051   I  1.0500    0.7625  0.2750   8.618248        3.657085
# 1  74052   I  1.1625    0.8875  0.2750  15.507176        7.030676
# 2  74053   F  1.2875    0.9875  0.3250  14.571643        5.556502
# 3  74054   F  1.5500    0.9875  0.3875  28.377849       13.380964
# 4  74055   I  1.1125    0.8500  0.2625  11.765042        5.528153
#
#    Viscera Weight  Shell Weight
# 0        1.729319      2.721552
# 1        3.246018      3.968930
# 2        3.883882      4.819415
# 3        6.548735      7.030676
# 4        2.466407      3.331066

# %%
df_test.isnull().sum()
# Out:
# id                0
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Weight            0
# Shucked Weight    0
# Viscera Weight    0
# Shell Weight      0
# dtype: int64

# %%
df_test.columns
# Out:
# Index(['id', 'Sex', 'Length', 'Diameter', 'Height', 'Weight', 'Shucked Weight',
#        'Viscera Weight', 'Shell Weight'],
#       dtype='object')

# %%
df_test.describe()
# Out:
#                   id        Length      Diameter        Height        Weight  \
# count   49368.000000  49368.000000  49368.000000  49368.000000  49368.000000
# mean    98734.500000      1.319795      1.026357      0.348693     23.464627
# std     14251.458382      0.286950      0.236593      0.092259     12.641703
# min     74051.000000      0.187500      0.137500      0.000000      0.056699
# 25%     86392.750000      1.162500      0.887500      0.300000     13.536886
# 50%     98734.500000      1.387500      1.075000      0.362500     23.813580
# 75%    111076.250000      1.537500      1.200000      0.412500     32.290081
# max    123418.000000      2.037500      1.625000      2.825000     80.101512
#
#        Shucked Weight  Viscera Weight  Shell Weight
# count    49368.000000    49368.000000  49368.000000
# mean        10.130220        5.072615      6.745876
# std          5.611779        2.791563      3.575650
# min          0.028349        0.014175      0.042524
# 25%          5.740774        2.877474      3.968930
# 50%          9.979024        4.989512      6.945627
# 75%         14.047177        7.016501      9.171063
# max         42.184056       21.545620     28.491248

# %%
df_test["Sex"]=label_encoder.fit_transform(df_test["Sex"])
df_test.head()
# Out:
#       id  Sex  Length  Diameter  Height     Weight  Shucked Weight  \
# 0  74051    1  1.0500    0.7625  0.2750   8.618248        3.657085
# 1  74052    1  1.1625    0.8875  0.2750  15.507176        7.030676
# 2  74053    0  1.2875    0.9875  0.3250  14.571643        5.556502
# 3  74054    0  1.5500    0.9875  0.3875  28.377849       13.380964
# 4  74055    1  1.1125    0.8500  0.2625  11.765042        5.528153
#
#    Viscera Weight  Shell Weight
# 0        1.729319      2.721552
# 1        3.246018      3.968930
# 2        3.883882      4.819415
# 3        6.548735      7.030676
# 4        2.466407      3.331066

# %% [markdown]
# # Submit My Result

# %%
my_prediction=cat_model.predict(df_test)
my_submission=pd.DataFrame({'id':df_test.id,'Age':my_prediction})
my_submission.to_csv('submission.csv',index=False)
